# %%
#Noah Greski - Testing Data ML project

#imports
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#read in data
housing_data = pd.read_csv(Path("housing data.csv"))
housing_data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
housing_data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
#check for missing values
housing_data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
#create dataframe with only numerical data
housing_num = housing_data.select_dtypes(include=[np.number])
housing_num.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992

# %%
#visualize the data
g = sns.PairGrid(housing_num)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/d81c48bn5z35dkwcws02wvcr0000gn/T/ipykernel_91858/1275994027.py in <module>
#       1 #visualize the data
#       2 g = sns.PairGrid(housing_num)
# ----> 3 g.map_diag(sns.histplot())
#       4 g.map_offdiag(sns.scatterplot())
#       5 g.add_legend()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1442                 group = diag_axes[0].get_shared_y_axes()
#    1443                 for ax in diag_axes[1:]:
# -> 1444                     group.join(ax, diag_axes[0])
#    1445
#    1446             self.diag_vars = np.array(diag_vars, np.object_)
#
# AttributeError: 'GrouperView' object has no attribute 'join'

# %%
#visual the housing prices
plt.xlim = (0, 1000000)
housing_data.sort_values(by = 'price', ascending = False)
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# ...                   ...         ...       ...        ...          ...
# 4472  2014-06-09 00:00:00         0.0       4.0       3.75         4060
# 4567  2014-07-02 00:00:00         0.0       4.0       2.50         4080
# 4354  2014-05-05 00:00:00         0.0       3.0       1.75         1490
# 4454  2014-06-03 00:00:00         0.0       5.0       2.50         2090
# 4382  2014-05-12 00:00:00         0.0       5.0       4.50         4630
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#housing_data['price'].hist(bins =10)
plt.figure(figsize=(10, 6))
plt.hist(housing_data['price'], bins=20, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.title('Histogram of Prices')
plt.xlabel('Price (Tens of Millions)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Separate the houses by price over/under $5 million
condition_value = 1000000  # Million dollar homes
condition_column = 'price'  # Sort by price

# Split based on condition
over = housing_data[housing_data['price'] >= condition_value]
under = housing_data[housing_data['price'] < condition_value]

print("Homes Over $1m: ", len(over), "\nHomes Under $1m: ", len(under))
# Out:
# Homes Over $1m:  344
# Homes Under $1m:  4256

# %%
# Revisualize for o/u $1m homes
plt.figure(figsize=(10, 6))
plt.hist(under['price'], bins=10, color='blue', edgecolor='black') # <$1m
plt.title('Histogram of Home Prices Under $1m')
plt.xlabel('Price (Hundreds of Thousands)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(over['price'], bins=50, color='red', edgecolor='black') # >=$1m
plt.title('Histogram of Home Prices Under $1m')
plt.xlabel('Price (Tens of Millions)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
